# %%
# !pip install numpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 37.3 MB/s eta 0:00:00:00:0100:01
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import os

# %%
OUTPUT_PATH = "/itet-stor/kvulic//neuronies/single_neurons/4_Varia/KV_testing/240923_output/Sorter_ID1708_N0_DIV22_DATE20240919_1632_spontaneous_NGN2.raw.h5/"

# %%
data = np.load(os.path.join(OUTPUT_PATH, "template_metrics.npy"), allow_pickle=True)

# %%
data
# Out:
# array([[nan, np.float64(0.000315), 1, 1, np.float64(0.00155),
#         np.float32(-0.06662488), np.float64(-1137.737541135021),
#         np.float64(173534.679473773), np.float64(175.0), nan, nan],
#        [nan, np.float64(0.00038), 1, 0, np.float64(0.00058),
#         np.float32(-0.11015315), np.float64(-8593.175054151729),
#         np.float64(262373.9094288407), np.float64(105.0), nan, nan],
#        [nan, np.float64(0.000335), 1, 2, np.float64(0.00128),
#         np.float32(-0.14179084), np.float64(-55063.32615589388),
#         np.float64(140291.6519986077), np.float64(175.0), nan, nan],
#        [nan, np.float64(0.000345), 1, 1, np.float64(0.001355),
#         np.float32(-0.06973727), np.float64(-17669.286820930418),
#         np.float64(210878.01045394415), np.float64(175.0), nan, nan],
#        [nan, np.float64(0.000445), 1, 2, np.float64(0.00063),
#         np.float32(-0.5049744), np.float64(-92717.3852504495),
# ...

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 40.0 MB/s eta 0:00:00:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 kB 15.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 10.2 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
