# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# %%
# Load the CSV file
filepath = '/itet-stor/kvulic/neuronies/single_neurons/1_Subprojects/Neurons_As_DNNs/3_Processed_Data/Imaging'
df = pd.read_csv(os.path.join(filepath, 'Directionality_quantification.csv'))

# %%
cross_tab = pd.crosstab(df['PDMS'], df['Direction'])

# Reorder the data to match the desired order: 'P' (Straight), 'H' (Heart), 'EP' (En Passant)
desired_order = ['P', 'H', 'EP']
percentages = cross_tab.div(cross_tab.sum(axis=1), axis=0) * 100
ordered_percentages = percentages.loc[desired_order]
ordered_totals = cross_tab.loc[desired_order].sum(axis=1)

# Update x_labels to match the new order
pdms_names = {
    'P': 'Straight',
    'H': 'Heart',
    'EP': 'En Passant'
}
x_labels = [f"{pdms_names[pdms]}\nN={ordered_totals[pdms]}" for pdms in desired_order]

# Set up the plot
plt.figure(figsize=(6, 6))

# Create the bar chart in the desired order
bar_width = 0.35
index = np.arange(len(desired_order))
bars1 = plt.bar(index, ordered_percentages['F'], bar_width, color='dimgray', label='Forward')
bars2 = plt.bar(index, ordered_percentages['B'], bar_width, bottom=ordered_percentages['F'], 
                color='dimgray', alpha=0.5, label='Backward')

plt.xlabel('PDMS Type', fontsize=20)
plt.ylabel('Neurite Growth Direction [%]', fontsize=20)
plt.xticks(index, x_labels, fontsize=18)
plt.yticks(fontsize=18)
plt.grid(True, axis="y", linestyle=':', alpha=0.7)
plt.legend(fontsize=16)

# Add percentage labels on the bars
def add_labels(bars, percentages):
    for bar in bars:
        height = bar.get_height()
        if height > 0:  # Add label for all bars
            plt.text(bar.get_x() + bar.get_width()/2., bar.get_y() + height/2.,
                     f'{int(height)}%', ha='center', va='center', color='white', fontweight='bold', fontsize=12)

add_labels(bars1, percentages['F'])
add_labels(bars2, percentages['B'])

plt.ylim(0, 110)  # Extend y-axis to make room for the count labels
plt.tight_layout()
plt.savefig(os.path.join(filepath, 'directionality_percentages.png'), dpi=300)
plt.savefig(os.path.join(filepath, 'directionality_percentages.pdf'), dpi=300)
plt.show()
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %%
cross_tab = pd.crosstab(df['PDMS'], df['Direction'])

# Calculate percentages for each PDMS type
percentages = cross_tab.div(cross_tab.sum(axis=1), axis=0) * 100

# Create a mapping for the full names
pdms_names = {
    'P': 'Plain',
    'H': 'Heart',
    'EP': 'En Passant'
}

# Set up the plot
plt.figure(figsize=(6, 7))

# Set the color palette - different shades of blue
blues = sns.color_palette("Blues", n_colors=2)

# Create the bar chart
bar_width = 0.35
index = np.arange(len(percentages.index))

# Create the bar chart
bars1 = plt.bar(index, percentages['F'], bar_width, color='dimgray', label='Forward')
bars2 = plt.bar(index, percentages['B'], bar_width, bottom=percentages['F'], 
                color='dimgray', alpha=0.5, label='Backward')
# Calculate total count for each PDMS type
totals = cross_tab.sum(axis=1)

# Create x-labels with total counts
x_labels = [f"{pdms_names[pdms]}\nN={totals[pdms]}" for pdms in percentages.index]

# Add labels without title
plt.xlabel('PDMS Type', fontsize=20)
plt.ylabel('Neurite Growth Direction [%]', fontsize=20)
plt.xticks(index, x_labels, fontsize=18)
plt.yticks(fontsize=18)
plt.grid(True, axis="y", linestyle=':', alpha=0.7)

plt.legend(fontsize=16)

# Add percentage labels on the bars
def add_labels(bars, percentages):
    for bar in bars:
        height = bar.get_height()
        if height > 0:  # Add label for all bars
            plt.text(bar.get_x() + bar.get_width()/2., bar.get_y() + height/2.,
                     f'{int(height)}%', ha='center', va='center', color='white', fontweight='bold', fontsize=12)

add_labels(bars1, percentages['F'])
add_labels(bars2, percentages['B'])

plt.ylim(0, 110)  # Extend y-axis to make room for the count labels
plt.tight_layout()
plt.savefig(os.path.join(filepath, 'directionality_percentages.png'), dpi=300)
plt.savefig(os.path.join(filepath, 'directionality_percentages.pdf'), dpi=300)
plt.show()
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %%
# Count occurrences for each PDMS type and Direction
# Create a crosstab of the data
cross_tab = pd.crosstab(df['PDMS'], df['Direction'])

# Calculate percentages for each PDMS type
percentages = cross_tab.div(cross_tab.sum(axis=1), axis=0) * 100

# Create a mapping for the full names
pdms_names = {
    'P': 'Plain',
    'H': 'Heart',
    'EP': 'En Passant'
}

# Set up the plot
plt.figure(figsize=(6, 6))

# Reorder the data if needed
desired_order = ['EP', 'H', 'P']
ordered_percentages = percentages.loc[desired_order]
ordered_totals = cross_tab.loc[desired_order].sum(axis=1)

# Define colors for direction (not PDMS type)
forward_color = '#000080'  # Navy blue for Forward
backward_color = '#87CEFA'  # Light sky blue for Backward

# Create the bar chart
bar_width = 0.35
index = np.arange(len(ordered_percentages.index))

# Plot the data with consistent colors for directions
bars1 = plt.bar(index, ordered_percentages['F'], bar_width, 
                color=forward_color, label='Forward')
bars2 = plt.bar(index, ordered_percentages['B'], bar_width, 
                bottom=ordered_percentages['F'], 
                color=backward_color, label='Backward')

# Create x-labels with just the PDMS type names
x_labels = [f"{pdms_names[pdms]}" for pdms in desired_order]

# Add labels without title
plt.xlabel('PDMS Type', fontsize=14)
plt.ylabel('Percentage (%)', fontsize=14)
plt.xticks(index, x_labels, fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)

# Add percentage labels on the bars
def add_labels(bars, percentages):
    for bar in bars:
        height = bar.get_height()
        if height > 0:  # Add label for all bars
            plt.text(bar.get_x() + bar.get_width()/2., bar.get_y() + height/2.,
                    f'{height:.1f}%', ha='center', va='center', 
                    color='white', fontweight='bold', fontsize=12)

add_labels(bars1, ordered_percentages['F'])
add_labels(bars2, ordered_percentages['B'])

# Add total count at the top of each pillar
for i, total in enumerate(ordered_totals):
    plt.text(i, 101, f'N = {total}', ha='center', va='bottom', fontsize=12, fontweight='bold')

plt.ylim(0, 110)  # Extend y-axis to make room for the count labels
plt.tight_layout()
plt.savefig(os.path.join(filepath,'directionality_percentages.png'), dpi=300)
# Save the figure as a PDF
plt.savefig(os.path.join(filepath,'directionality_percentages.pdf'), dpi=300)
plt.show()

# %%
# Count occurrences for each PDMS type and Direction
# Create a crosstab of the data
cross_tab = pd.crosstab(df['PDMS'], df['Direction'])

# Calculate percentages for each PDMS type
percentages = cross_tab.div(cross_tab.sum(axis=1), axis=0) * 100

# Create a mapping for the full names
pdms_names = {
    'P': 'Plain',
    'H': 'Heart',
    'EP': 'En Passant'
}

# Set up the plot
plt.figure(figsize=(6, 6))

# Define the custom color palette with the requested colors
blue_palette = ['#000080', '#4682B4', '#00BFFF']  # Navy, Steel Blue, Deep Sky Blue

# Create the bar chart
bar_width = 0.35
index = np.arange(len(percentages.index))

# Reorder the data to match the desired color order: En Passant, Heart, Plain
desired_order = ['EP', 'H', 'P']
ordered_percentages = percentages.loc[desired_order]
ordered_totals = cross_tab.loc[desired_order].sum(axis=1)

# Plot the data with different alpha values
bars1 = plt.bar(index, ordered_percentages['F'], bar_width, 
                color=blue_palette, alpha=1.0, label='Forward')
bars2 = plt.bar(index, ordered_percentages['B'], bar_width, 
                bottom=ordered_percentages['F'], 
                color=blue_palette, alpha=0.5, label='Backward')

# Create x-labels with just the PDMS type names
x_labels = [f"{pdms_names[pdms]}" for pdms in desired_order]

# Add labels without title
plt.xlabel('PDMS Type', fontsize=14)
plt.ylabel('Percentage (%)', fontsize=14)
plt.xticks(index, x_labels, fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)

# Add percentage labels on the bars
def add_labels(bars, percentages):
    for bar in bars:
        height = bar.get_height()
        if height > 0:  # Add label for all bars
            plt.text(bar.get_x() + bar.get_width()/2., bar.get_y() + height/2.,
                    f'{height:.1f}%', ha='center', va='center', 
                    color='white', fontweight='bold', fontsize=12)

add_labels(bars1, ordered_percentages['F'])
add_labels(bars2, ordered_percentages['B'])

# Add total count at the top of each pillar
for i, total in enumerate(ordered_totals):
    plt.text(i, 101, f'N = {total}', ha='center', va='bottom', fontsize=12, fontweight='bold')

plt.ylim(0, 110)  # Extend y-axis to make room for the count labels
plt.tight_layout()
plt.savefig(os.path.join(filepath,'directionality_percentages.png'), dpi=300)
# Save the figure as a PDF
plt.savefig(os.path.join(filepath,'directionality_percentages.pdf'), dpi=300)
plt.show()
# Out:
# Overall Summary Statistics:
# Mean Percentage Filled: 80.9%
# Standard Deviation: 18.2%
# Coefficient of Variation: 22.5%
# Minimum: 38.9%
# Maximum: 97.2%
# Range: 58.3%
#
# Statistical Summary by Channel Count:
#        count   mean        std
# Total
# 144        5  62.24  15.752873
# 216        9  91.30   8.693101

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Assuming df['Percentage_Filled'], mean_percentage, and std_percentage are already defined

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 10))

# First subplot: Histogram (similar to your original)
sns.histplot(df['Percentage_Filled'], bins=7, kde=True, ax=ax1)
ax1.axvline(mean_percentage, color='red', linestyle='--', 
            label=f'Mean: {mean_percentage:.1f}%')
ax1.axvline(mean_percentage + std_percentage, color='green', linestyle=':', 
            label=f'Mean ± Std Dev: {std_percentage:.1f}%')
ax1.axvline(mean_percentage - std_percentage, color='green', linestyle=':')
ax1.set_title('Distribution of Channel Filling Percentages')
ax1.set_xlabel('Percentage Filled (%)')
ax1.set_ylabel('Frequency')
ax1.legend()

# Second subplot: CDF
# Method 1: Using ECDF from statsmodels
from statsmodels.distributions.empirical_distribution import ECDF
ecdf = ECDF(df['Percentage_Filled'])
ax2.step(ecdf.x, ecdf.y, where='post', label='CDF')

# Alternatively, Method 2: Using numpy's percentile function
# sorted_data = np.sort(df['Percentage_Filled'])
# y = np.arange(1, len(sorted_data)+1) / len(sorted_data)
# ax2.step(sorted_data, y, where='post', label='CDF')

# Add reference lines
ax2.axvline(mean_percentage, color='red', linestyle='--', 
           label=f'Mean: {mean_percentage:.1f}%')
ax2.axvline(mean_percentage + std_percentage, color='green', linestyle=':', 
           label=f'Mean + Std Dev: {mean_percentage + std_percentage:.1f}%')
ax2.axvline(mean_percentage - std_percentage, color='green', linestyle=':', 
           label=f'Mean - Std Dev: {mean_percentage - std_percentage:.1f}%')

# Add grid for easier reading of probability values
ax2.grid(True, linestyle='--', alpha=0.7)
ax2.set_title('Cumulative Distribution Function of Channel Filling Percentages')
ax2.set_xlabel('Percentage Filled (%)')
ax2.set_ylabel('Cumulative Probability')
ax2.legend()

# Add annotations to show percentage at specific points
# For example, what percent of channels are below 80% filled
threshold = 80
probability = ecdf(threshold)
ax2.plot([threshold, threshold], [0, probability], 'b--', alpha=0.5)
ax2.plot([0, threshold], [probability, probability], 'b--', alpha=0.5)
ax2.annotate(f'{probability:.2f}', 
             xy=(threshold, probability),
             xytext=(threshold-10, probability+0.05),
             arrowprops=dict(arrowstyle='->'))

plt.tight_layout()
plt.savefig('channel_filling_analysis_with_cdf.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Assuming df['Percentage_Filled'], mean_percentage, and std_percentage are already defined

plt.figure(figsize=(10, 6))

# Create a strip plot (dot plot with jittering)
# The jitter parameter controls the amount of horizontal displacement
ax = sns.stripplot(x=df['Percentage_Filled'], 
                   jitter=True, 
                   size=8,  # dot size
                   alpha=0.7,  # transparency
                   palette='viridis')  # color palette

# Add a box plot for statistical summary
# Set width small to not overwhelm the strip plot
sns.boxplot(x=df['Percentage_Filled'], 
            width=0.3, 
            color='lightgray', 
            showfliers=False,  # hide outlier markers
            ax=ax)

# Add a small swarm plot variation for comparison
# sns.swarmplot(x=df['Percentage_Filled'], 
#               color='black', 
#               size=5, 
#               alpha=0.5)

# Add reference lines
plt.axvline(mean_percentage, color='red', linestyle='--', 
            label=f'Mean: {mean_percentage:.1f}%')
plt.axvline(mean_percentage + std_percentage, color='green', linestyle=':', 
            label=f'Mean + Std Dev: {mean_percentage + std_percentage:.1f}%')
plt.axvline(mean_percentage - std_percentage, color='green', linestyle=':', 
            label=f'Mean - Std Dev: {mean_percentage - std_percentage:.1f}%')

# Add a rug plot at the bottom to show data density
sns.rugplot(df['Percentage_Filled'], color='black', height=0.05)

# Enhance the plot with descriptive elements
plt.title('Distribution of Channel Filling Percentages (Individual Observations)')
plt.xlabel('Percentage Filled (%)')
plt.ylabel('')  # Remove y-label as it's not meaningful in a strip plot

# Add text annotations for key statistics
stats_text = (f"n = {len(df['Percentage_Filled'])}\n"
              f"Mean = {mean_percentage:.1f}%\n"
              f"SD = {std_percentage:.1f}%\n"
              f"Min = {df['Percentage_Filled'].min():.1f}%\n"
              f"Max = {df['Percentage_Filled'].max():.1f}%")
              
plt.annotate(stats_text, 
             xy=(0.02, 0.98),
             xycoords='axes fraction',
             va='top',
             bbox=dict(boxstyle='round', fc='white', alpha=0.8))

plt.legend()
plt.tight_layout()
plt.savefig('channel_filling_dotplot.png', dpi=300)
plt.show()
# Out:
# /tmp/ipykernel_994/2920647884.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x=df['Percentage_Filled'],

# %%
# Calculate the percentage filled
df['Percentage_Filled'] = (df['Filled'] / df['Total'] * 100).round(1)

# Create a more descriptive experiment label
df['Experiment'] = df['PDMS'] + ' - Sample ' + df['Sample'].astype(str)

# Create the visualization
plt.figure(figsize=(7, 6))

# Create a custom blue color palette with different shades of blue
blue_palette = ['#000080', '#4682B4', '#00BFFF']  # Different shades of blue

# Option 2: Group by PDMS type with narrower box plots and blue shades
plt.subplot(1, 1, 1)
sns.boxplot(x='PDMS', y='Percentage_Filled', data=df, palette=blue_palette, width=0.5)  # Narrower width
sns.swarmplot(x='PDMS', y='Percentage_Filled', data=df, color='black', size=8)

# Custom x-axis labels
plt.xticks([0, 1, 2], ['En passant', 'Heart', 'Plain'])  # Replace EP, H, P with full names

#plt.title('Distribution of Filled Percentages by PDMS Type')
#plt.xlabel('PDMS Type')
plt.ylabel('% of Wells With Cells', fontsize = 14)
plt.xlabel('', fontsize = 3)
plt.ylim(0, 100)  # Set y-axis from 0 to 100%
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.savefig('channel_filling_analysis.png', dpi=300)
plt.show()

# Print summary statistics
print("Summary Statistics by PDMS Type:")
print(df.groupby('PDMS')['Percentage_Filled'].describe())
plt.savefig(os.path.join(filepath,'channel_filling_analysis.png'), dpi=300)
plt.savefig(os.path.join(filepath,'channel_filling_analysis.pdf'), dpi=300)
plt.show()
# Out:
# /tmp/ipykernel_994/3345172845.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='PDMS', y='Percentage_Filled', data=df, palette=blue_palette, width=0.5)  # Narrower width
# Summary Statistics by PDMS Type:
#       count    mean        std   min     25%    50%    75%   max
# PDMS
# EP      5.0  62.240  15.752873  38.9  54.200  66.70  75.00  76.4
# H       5.0  94.080   3.505995  88.0  94.400  95.40  95.80  96.8
# P       4.0  87.825  12.495966  69.4  86.425  92.35  93.75  97.2

# %%
df = pd.read_csv(os.path.join(filepath, 'Filled_quantification.csv'))
# Calculate the percentage filled
df['Percentage_Filled'] = (df['Filled'] / df['Total'] * 100).round(1)

# Create a more descriptive experiment label
df['Experiment'] = df['PDMS'] + ' - Sample ' + df['Sample'].astype(str)

# Create the visualization
plt.figure(figsize=(7, 6))

# Create a custom blue color palette with different shades of blue
blue_palette = ['#000080', '#4682B4', '#00BFFF']  # Different shades of blue

# Option 2: Group by PDMS type with narrower box plots and blue shades
plt.subplot(1, 1, 1)
sns.boxplot(x='PDMS', y='Percentage_Filled', data=df, palette=blue_palette, width=0.5)  # Narrower width
sns.swarmplot(x='PDMS', y='Percentage_Filled', data=df, color='black', size=8)

# Custom x-axis labels
plt.xticks([0, 1, 2], ['En passant', 'Heart', 'Plain'])  # Replace EP, H, P with full names

plt.ylabel('% of Wells With Cells', fontsize=14)
plt.xlabel('', fontsize=3)
plt.ylim(0, 120)  # Set y-axis from 0 to 100%
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Statistical analysis
import scipy.stats as stats
import numpy as np

# Perform one-way ANOVA
f_stat, p_value = stats.f_oneway(
    df[df['PDMS'] == 'EP']['Percentage_Filled'],
    df[df['PDMS'] == 'H']['Percentage_Filled'],
    df[df['PDMS'] == 'P']['Percentage_Filled']
)

print("\nStatistical Analysis:")
print(f"One-way ANOVA: F-statistic = {f_stat:.4f}, p-value = {p_value:.4f}")

# If ANOVA is significant, perform pairwise t-tests
if p_value < 0.05:
    print("The ANOVA test shows a significant difference between at least two groups (p < 0.05)")
    
    # Perform pairwise t-tests with Bonferroni correction
    pdms_types = ['EP', 'H', 'P']
    pdms_indices = {'EP': 0, 'H': 1, 'P': 2}
    
    print("\nPairwise t-tests (with Bonferroni correction):")
    
    y_max = df['Percentage_Filled'].max()
    y_buffer = 5  # Space above the highest point
    
    # Compare all pairs
    for i, group1 in enumerate(pdms_types):
        for j, group2 in enumerate(pdms_types[i+1:], i+1):
            t_stat, p_val = stats.ttest_ind(
                df[df['PDMS'] == group1]['Percentage_Filled'],
                df[df['PDMS'] == group2]['Percentage_Filled'],
                equal_var=False  # Use Welch's t-test which doesn't assume equal variance
            )
            
            print(f"{group1} vs {group2}: t-stat = {t_stat:.4f}, p-value = {p_val:.4f}")
            
            # Apply Bonferroni correction (multiply p-value by number of comparisons)
            bonferroni_p = p_val * 3  # 3 comparisons for 3 groups
            adjusted_sig = "not significant"
            
            if bonferroni_p < 0.05:
                idx1 = pdms_indices[group1]
                idx2 = pdms_indices[group2]
                
                # Height for multiple comparison bars if needed
                height = y_max + y_buffer + (5 * (j-i-1))
                
                plt.plot([idx1, idx2], [height, height], 'k-')
                
                # Add significance markers based on p-value
                if bonferroni_p < 0.001:
                    sig_symbol = '***'
                    adjusted_sig = "p < 0.001"
                elif bonferroni_p < 0.01:
                    sig_symbol = '**'
                    adjusted_sig = "p < 0.01"
                else:
                    sig_symbol = '*'
                    adjusted_sig = "p < 0.05"
                    
                plt.text((idx1 + idx2) / 2, height + 2, sig_symbol, 
                         ha='center', va='bottom', fontsize=16)
            
            print(f"  Bonferroni adjusted p-value = {bonferroni_p:.4f} ({adjusted_sig})")
else:
    print("The ANOVA test does not show a significant difference between the groups (p ≥ 0.05)")

# Print summary statistics
print("\nSummary Statistics by PDMS Type:")
print(df.groupby('PDMS')['Percentage_Filled'].describe())

# Save figures
plt.savefig(os.path.join(filepath, 'channel_filling_analysis_w_statistics.png'), dpi=300)
plt.savefig(os.path.join(filepath, 'channel_filling_analysis_W_statistics.pdf'), dpi=300)
plt.show()
# Out:
# /tmp/ipykernel_994/796586936.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='PDMS', y='Percentage_Filled', data=df, palette=blue_palette, width=0.5)  # Narrower width
# Statistical Analysis:
# One-way ANOVA: F-statistic = 10.2021, p-value = 0.0031
# The ANOVA test shows a significant difference between at least two groups (p < 0.05)
#
# Pairwise t-tests (with Bonferroni correction):
# EP vs H: t-stat = -4.4116, p-value = 0.0094
#   Bonferroni adjusted p-value = 0.0281 (p < 0.05)
# EP vs P: t-stat = -2.7171, p-value = 0.0299
#   Bonferroni adjusted p-value = 0.0897 (not significant)
# H vs P: t-stat = 0.9710, p-value = 0.3958
#   Bonferroni adjusted p-value = 1.1874 (not significant)
#
# Summary Statistics by PDMS Type:
#       count    mean        std   min     25%    50%    75%   max
# PDMS
# ...

# %% [markdown]
# Giulia style plotting

# %%
#import annotator
from statannotations.Annotator import Annotator
#import ticker
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(os.path.join(filepath, 'Filled_quantification.csv'))
# Calculate the percentage filled
df['Percentage_Filled'] = (df['Filled'] / df['Total'] * 100).round(1)

# Create a more descriptive experiment label
df['Experiment'] = df['PDMS'] + ' - Sample ' + df['Sample'].astype(str)

# %%
def custom_boxplot(data, x_metric, y_metric, hue_metric, axes, labely, fontsize=16, labelsize=14, position_line=-0.12):
 
    # Plot the strip plot
    sns.boxplot(data=data, x=x_metric, y=y_metric, color = 'dimgray',
                 legend=False, zorder=1, ax=axes, width=0.4, fliersize=0, showfliers=False)
 
    # Add statistical annotations
    pairs = [
        ("H", "P"),
        ("EP", "H"),
        ("P", "EP"),
    ]
 
    print(data.columns)
    annotator = Annotator(axes, pairs, data=data, x=hue_metric, y=y_metric)
    annotator.configure(test='Kruskal', text_format='star', loc='inside', fontsize=fontsize, hide_non_significant=True)
    print(f"\nAnnotate for metric {y_metric}")
    annotator.apply_and_annotate()
    
    plt.rcParams['xtick.bottom'] = True
    plt.rcParams['ytick.left'] = True
    plt.rcParams['font.family'] = 'Arial'
    axes.set_ylabel(labely, fontsize=fontsize)
    axes.set_xlabel("", fontsize=fontsize)
    axes.grid(True, axis="y", linestyle=':', alpha=0.7)
    axes.tick_params(axis='both', which='major', labelsize=labelsize, width=1.5, length=8)
    #axes.yaxis.set_major_locator(ticker.MaxNLocator(5))
    
    # Add grouped x-axis labels
    axes.tick_params(axis='both', which='major')
    xticks = axes.get_xticks()  # Positions of "Soft", "Inter", "Stiff", etc.
    print(xticks)
    axes.set_xticks(xticks)  # Position of ticks
    axes.set_xticklabels(["En Passant", "Heart", "Straight"])
    
    # Get relative x-ticks position
    x_min, x_max = axes.get_xlim()
    #ticks = [(tick - x_min) / (x_max - x_min) for tick in axes.get_xticks()]
    plt.savefig(os.path.join(filepath, 'channel_filling_analysis_w_statistics.png'), dpi=300)
    plt.savefig(os.path.join(filepath, 'channel_filling_analysis_w_statistics.pdf'), dpi=300)

# %%
fig, ax = plt.subplots(figsize=(8,6))
custom_boxplot(df, 'PDMS', 'Percentage_Filled', 'PDMS', ax, labely='Percentage of Wells With Cells [%]')
# Out:
# Index(['PDMS', 'Filled', 'Sample', 'Total', 'Percentage_Filled', 'Experiment'], dtype='object')
#
# Annotate for metric Percentage_Filled
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# EP vs. H: Kruskal-Wallis independent samples (pairwise between groups), P_val:9.023e-03 Stat=6.818e+00
# [0, 1, 2]

# %%
|

# %%
fig, ax = plt.subplots(figsize=(6,6))
custom_boxplot(df, 'PDMS', 'Percentage_Filled', 'PDMS', ax, labely='Percentage of Wells With Cells [%]')
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
df = pd.read_csv(os.path.join(filepath, 'Filled_quantification.csv'))
# Calculate the percentage filled
df['Percentage_Filled'] = (df['Filled'] / df['Total']).round(1)

# Create a more descriptive experiment label
df['Experiment'] = df['PDMS'] + ' - Sample ' + df['Sample'].astype(str)

# %%
def custom_boxplot_binomial(data, x_metric, y_metric, hue_metric, axes, labely, fontsize=20, labelsize=18, position_line=-0.12):
    import numpy as np
    import seaborn as sns
    import matplotlib.pyplot as plt
    import os
    #remove warnings
    import warnings
    warnings.filterwarnings("ignore", category=UserWarning, module='seaborn')
    
    # Define the mapping from dataframe values to display labels
    label_mapping = {
        "P": "Straight",
        "H": "Heart", 
        "EP": "En-Passant"
    }
    
    # Set the desired order for x-axis categories (in terms of dataframe values)
    data_order = ["P", "H", "EP"]  # This corresponds to Straight, Heart, En Passant
    
    # Plot the boxplot with the data order
    sns.boxplot(data=data, x=x_metric, y=y_metric, color='dimgray',
                order=data_order, legend=False, zorder=1, ax=axes, width=0.4, 
                fliersize=0, showfliers=False)
    
    # Calculate binomial confidence intervals for each category
    binomial_errors = {}
    for category in data_order:
        category_data = data[data[x_metric] == category][y_metric]
        n = len(category_data)
        p = category_data.mean()  # proportion/mean

        print(n,p)
        
        # Calculate binomial standard error: sqrt(p(1-p)/n)
        if n > 0 and 0 < p < 1:
            error = 100 * np.sqrt((p * (1 - p)) / n)
        else:
            error = 0
        
        binomial_errors[category] = {
            'mean': p,
            'error': error,
            'n': n
        }
        
        print(f"{label_mapping[category]}: mean={p:.3f}, error=±{error:.1f}%, n={n}")
    
    # Add error bars to the boxplot
    x_positions = range(len(data_order))
    for i, category in enumerate(data_order):
        mean_val = binomial_errors[category]['mean']
        error_val = binomial_errors[category]['error'] / 100  # Convert back to proportion
        
        # Add error bars
        axes.errorbar(i, mean_val, yerr=error_val, 
                     fmt='o', color='red', markersize=6, 
                     capsize=5, capthick=2, elinewidth=2,
                     zorder=10, label='Binomial CI' if i == 0 else "")
    
    # Add text annotations showing the error percentages
    for i, category in enumerate(data_order):
        error_pct = binomial_errors[category]['error']
        mean_val = binomial_errors[category]['mean']
        axes.text(i, mean_val + 0.05, f'±{error_pct:.1f}%', 
                 ha='center', va='bottom', fontsize=fontsize-4, 
                 bbox=dict(boxstyle='round,pad=0.3', facecolor='white', alpha=0.8))
    
    plt.rcParams['xtick.bottom'] = True
    plt.rcParams['ytick.left'] = True
    axes.set_ylabel(labely, fontsize=fontsize)
    axes.set_xlabel("", fontsize=fontsize)
    axes.grid(True, axis="y", linestyle=':', alpha=0.7)
    axes.tick_params(axis='both', which='major', labelsize=labelsize, width=1.5, length=8)
    
    # Set the display labels based on the data order
    display_labels = [label_mapping[cat] for cat in data_order]
    
    # Update x-tick labels with the mapped display names
    axes.tick_params(axis='both', which='major')
    xticks = axes.get_xticks()
    axes.set_xticks(xticks)
    axes.set_xticklabels(display_labels)
    
    # Add legend for error bars
    axes.legend(loc='upper right', fontsize=labelsize-2)
    
    plt.savefig(os.path.join(filepath, 'channel_filling_analysis_w_binomial_errors.png'), dpi=300)
    plt.savefig(os.path.join(filepath, 'channel_filling_analysis_w_binomial_errors.pdf'), dpi=300)

# %%
fig, ax = plt.subplots(figsize=(6,6))
custom_boxplot_binomial(df, 'PDMS', 'Percentage_Filled', 'PDMS', ax, labely='Percentage of Wells With Cells [%]')
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...
